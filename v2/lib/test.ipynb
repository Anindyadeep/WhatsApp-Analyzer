# %% [markdown]
# ## **TESTING THE WHATSAPP V1.0.1**

# %%
from functions import WpFunctions
from visualize import WpVisualize

# %%
test_path = "/home/anindya/Documents/project_wp/WPv1.0.1/v2/lib/WhatsApp Chat with Bro code clan 🧑‍💻🧑‍💻.txt"

# %%
wpf = WpFunctions(test_path)
wpv = WpVisualize(test_path)

# %% [markdown]
# ## **TESTING THE `WpFuntions` CLASS**

# %%
# getting the statstics data

wpf.get_stats_frame().head()
# Out:
#                User  Total_msg  Total_media  Total_link             Emojies  \
# 0   +91 80937 87472         35            5           0  [🥲, 🌝, 😂, 🥺, 😘, 🤞]
# 1   +91 76651 80930        181           69           3                 [🥲]
# 2   +91 87635 43695        121           37           2     [🙌, 😂, 😌, 🤣, 🤧]
# 3           Anindya         51            3           0        [🤔, 🥲, 🎂, 😅]
# 4         Sashikant        524          121          11              [😂, 😅]
#
#    Total_emojies
# 0              6
# 1              1
# 2              5
# 3              4
# 4              2

# %%
wpf.get_all_emojies_used().head()
# Out:
#   Emoji              Emoji_desc  Emoji_frequency
# 0     🥲  smiling_face_with_tear                5
# 1     🌝          full_moon_face                1
# 2     😂  face_with_tears_of_joy               10
# 3     🥺           pleading_face                1
# 4     😘     face_blowing_a_kiss                1

# %%
wpf.get_data_to_plot()
# Out:
#                Date_Time        Date     Time              User  \
# 0    2021-06-18 16:55:00  18/06/2021   16:55    +91 80937 87472
# 1    2021-06-19 11:13:00  19/06/2021   11:13    +91 76651 80930
# 2    2021-06-19 11:14:00  19/06/2021   11:14    +91 87635 43695
# 3    2021-06-19 11:14:00  19/06/2021   11:14            Anindya
# 4    2021-06-19 11:23:00  19/06/2021   11:23          Sashikant
# ...                  ...         ...      ...               ...
# 2984 2021-09-15 11:06:00  15/09/2021   11:06          Sashikant
# 2985 2021-09-15 11:06:00  15/09/2021   11:06    +91 95235 78653
# 2986 2021-09-15 11:07:00  15/09/2021   11:07          Sashikant
# 2987 2021-09-15 14:26:00  15/09/2021   14:26    +91 99104 68260
# 2988 2021-09-15 14:32:00  15/09/2021   14:32    +91 79035 11342
#
#                                                     Msg  \
# 0                                     <Media omitted>\n
# 1                                     <Media omitted>\n
# ...

# %%
wpf.get_full_track_msgs('ALL')
# Out:
# The name of the user is:   +91 70083 80068
# The total no of messages sent by  +91 70083 80068  is:  59
# The total number of media (including the pics, vids, gifs, stickers by  +91 70083 80068  is:  10
# The total number of links sent by  +91 70083 80068  is:  0
# The total number of emojies sent by  +91 70083 80068  is:  5
# The emojies used by  +91 70083 80068  are:  ['😕', '😂', '🙏', '🤣', '🙇🏻\u200d♂️']
#
#
# The name of the user is:   +91 6289 047 612
# The total no of messages sent by  +91 6289 047 612  is:  160
# The total number of media (including the pics, vids, gifs, stickers by  +91 6289 047 612  is:  28
# The total number of links sent by  +91 6289 047 612  is:  1
# The total number of emojies sent by  +91 6289 047 612  is:  2
# The emojies used by  +91 6289 047 612  are:  ['😑', '😂']
#
#
# The name of the user is:   +91 87635 43695
# The total no of messages sent by  +91 87635 43695  is:  121
# ...

# %%
wpf.get_full_track_msgs('Anindya')
# Out:
# The name of the user is:   Anindya
# The total no of messages sent by  Anindya  is:  51
# The total number of media (including the pics, vids, gifs, stickers by  Anindya  is:  3
# The total number of links sent by  Anindya  is:  0
# The total number of emojies sent by  Anindya  is:  4
# The emojies used by  Anindya  are:  ['🤔', '\U0001f972', '🎂', '😅']

# %% [markdown]
# ## **TESTING THE `WpVisualize` CLASS**

# %%
wpv.get_active_days('ALL')

# %%
wpv.get_active_times('ALL')

# %%
wpv.make_word_cloud('Sashikant')

# %%
wpv.plot_emoji_frequency()

# %%
wpv.plot_user_media_freq()

# %%
wpv.plot_user_emoji_freq()

# %%
wpv.plot_user_link_freq()

# %%
wpv.plot_user_msg_freq()

# %%
# tracking any user full flegedly

wpv.track_me('ALL')
# Out:
# ####### THE TOTAL TRACK RECORD OF THE USER #######
#
# ALL USERS:
# The name of the user is:   +91 70083 80068
# The total no of messages sent by  +91 70083 80068  is:  59
# The total number of media (including the pics, vids, gifs, stickers by  +91 70083 80068  is:  10
# The total number of links sent by  +91 70083 80068  is:  0
# The total number of emojies sent by  +91 70083 80068  is:  5
# The emojies used by  +91 70083 80068  are:  ['😕', '😂', '🙏', '🤣', '🙇🏻\u200d♂️']
#
#
# The name of the user is:   +91 6289 047 612
# The total no of messages sent by  +91 6289 047 612  is:  160
# The total number of media (including the pics, vids, gifs, stickers by  +91 6289 047 612  is:  28
# The total number of links sent by  +91 6289 047 612  is:  1
# The total number of emojies sent by  +91 6289 047 612  is:  2
# The emojies used by  +91 6289 047 612  are:  ['😑', '😂']
#
#
# The name of the user is:   +91 87635 43695
# The total no of messages sent by  +91 87635 43695  is:  121
# ...
